# %% [markdown]
# # Comparing two normal distributions (with random effects)

# %%
# Data processing
import numpy as np
import pandas as pd

# Data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk')
sns.set_style('dark')

# Statistical modelling
import pymc3 as pm

import theano 
import theano.tensor as tt

import patsy
import scipy.stats as st

# %%
# filter some annoying warnings
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Set seed of the random number generator for reproducibility
SEED = 880123

# %% [markdown]
# ## The story

# %% [markdown]
# ![traffic](..\images\traffic.jpg)

# %% [markdown]
# > Let's image that you have collected some data on highway driving. Some people were driving manually, whereas some others were using adaptive cruise control (ACC). You want to investigate if there is any difference in speed between manual driving and driving with ACC. The hypothesis is that ACC, by automating the longitudinal control of the car, will have an impact on the speed people travel at.

# %% [markdown]
# ## Generate artificial data

# %%
n_driving_mode = 2
n_drivers = 15
n_samples_per_driving_mode = 25

between_driver_sd = np.array([0.5, 0.5])

# %%
drivers = ['Driver_{:02}'.format(i+1) for i in range(n_drivers)]
drivers
# Out:
# ['Driver_01',
#  'Driver_02',
#  'Driver_03',
#  'Driver_04',
#  'Driver_05',
#  'Driver_06',
#  'Driver_07',
#  'Driver_08',
#  'Driver_09',
#  'Driver_10',
#  'Driver_11',
#  'Driver_12',
#  'Driver_13',
#  'Driver_14',
#  'Driver_15']

# %%
mu_fixed_effect = np.array([100, 100])
sd_fixed_effect = np.array([2, 0.5])

# %%
# I draw the mu for each driver
# I draw the mu for each driver
mu_driver = np.random.normal(loc=mu_fixed_effect, scale=between_driver_sd, size=(n_drivers, n_driving_mode))
mu_driver.mean(axis=0), mu_driver.std(axis=0)
# Out:
# (array([ 99.90912665, 100.06136628]), array([0.51391721, 0.55419341]))

# %%
plt.plot(np.array([0, 1]), mu_driver.T, marker='o');
plt.xticks([0, 1], (['Manual', 'ACC']))
pass

# %%
# I draw the sd for each driver
sd_driver = np.random.normal(loc=sd_fixed_effect, scale=between_driver_sd, size=(n_drivers, n_driving_mode))
sd_driver = np.abs(sd_driver)
sd_driver.mean(axis=0), sd_driver.std(axis=0)
# Out:
# (array([1.95548337, 0.67226669]), array([0.44970662, 0.48550626]))

# %%
#draw observations around the mean for each driver and each driving mode
obs = np.random.normal(loc=mu_driver, scale=sd_driver, size=(n_samples_per_driving_mode, n_drivers, n_driving_mode))
obs.shape
# Out:
# (25, 15, 2)

# %%
data = pd.DataFrame(
        {
            'speed':np.concatenate((obs[:, :, 0].flatten(order='C'), obs[:, :, 1].flatten(order='C'))),
            'driver':np.tile(drivers, reps=n_samples_per_driving_mode*n_driving_mode),
            'ACC_active':np.concatenate((np.zeros(n_samples_per_driving_mode*n_drivers), np.ones(n_samples_per_driving_mode*n_drivers)))
        }

)

# %%
data['ACC_active'] = data['ACC_active'].astype('int')
data['driver'] = data['driver'].astype('category')

# %%
data.head()
# Out:
#         speed     driver  ACC_active
# 0   99.066011  Driver_01           0
# 1  103.135648  Driver_02           0
# 2   99.192001  Driver_03           0
# 3   99.099975  Driver_04           0
# 4   97.339091  Driver_05           0

# %%
sns.lmplot(x='ACC_active', y='speed', hue='driver', data=data, ci=None, x_jitter=0.01, scatter_kws=dict(alpha=0.1))
plt.xlim((-0.1, 1.1))
plt.ylim((90, 110))
plt.xticks([0, 1], (['Manual', 'ACC']))

pass

# %%
sns.distplot(data.loc[data['ACC_active']==0, 'speed'])
sns.distplot(data.loc[data['ACC_active']==1, 'speed'])

pass

# %%
data.groupby('ACC_active').agg(['mean', 'std'])
# Out:
#                  speed
#                   mean       std
# ACC_active
# 0           100.053167  2.125740
# 1           100.097487  0.941979

# %% [markdown]
# A first look suggests that manual driving has higher speed variability than ACC driving. Moreover, it seems that, on average, the speed is not much different between manual driving and ACC driving. A possible explanation is that the activation of ACC reduce the human variability in maintaining the speed and the headway to the lead vehicle. Each driver, however, shows a slightly different effect of ACC on their driving behavior. Some drivers lowered their speed, whereas some other increased theirs.
#
# We will estimate the difference in average speed and variability with Bayesian modelling. Thanks to the Bayesian method we will also obtain the uncertainty of the estimation.

# %% [markdown]
# ## Bayesian modelling

# %%
X = patsy.dmatrix('1 + ACC_active', data=data)
Z_intercept = patsy.dmatrix('0 + driver', data=data)
Z_slope = patsy.dmatrix('0 + driver:ACC_active', data=data)
X.shape, Z_intercept.shape, Z_slope.shape
# Out:
# ((750, 2), (750, 15), (750, 15))

# %%
data.head()
# Out:
#         speed     driver  ACC_active
# 0   99.066011  Driver_01           0
# 1  103.135648  Driver_02           0
# 2   99.192001  Driver_03           0
# 3   99.099975  Driver_04           0
# 4   97.339091  Driver_05           0

# %%
# Sampler settings
BURNIN=1000
TUNE=1000
SAMPLES=1000

# %% [markdown]
# ### Build the model

# %%
with pm.Model() as model:
    
    ## 'mu' Fixed effect
    beta_mu_intercept = pm.Normal('beta_mu_intercept', mu=data['speed'].mean(), sd=5)
    beta_mu_slope = pm.Normal('beta_mu_slope', mu=0, sd=5)
    beta_mu = tt.stack(beta_mu_intercept, beta_mu_slope)
    
    ## 'mu' Random effect
    # intercept
    gamma_mu_intercept_sd = pm.HalfNormal('gamma_mu_intercept_sd', sd=5)
    gamma_mu_intercept_raw = pm.Normal('gamma_mu_intercept_raw', mu=0, sd=1, shape=Z_intercept.shape[1])
    gamma_mu_intercept = pm.Deterministic('gamma_mu_intercept', gamma_mu_intercept_raw * gamma_mu_intercept_sd)
    
    # slope
    gamma_mu_slope_sd = pm.HalfNormal('gamma_mu_slope_sd', sd=5)
    gamma_mu_slope_raw = pm.Normal('gamma_mu_slope_raw', mu=0, sd=1, shape=Z_slope.shape[1])
    gamma_mu_slope = pm.Deterministic('gamma_mu_slope', gamma_mu_slope_raw * gamma_mu_slope_sd)  
        
    mu = tt.dot(np.asarray(X), beta_mu) + \
         tt.dot(np.asarray(Z_intercept), gamma_mu_intercept) + \
         tt.dot(np.asarray(Z_slope), gamma_mu_slope)

    ## 'sd' Fixed effect
    beta_sd_intercept = pm.Normal('beta_sd_intercept', mu=0, sd=2)
    beta_sd_slope = pm.Normal('beta_sd_slope', mu=0, sd=2)
    beta_sd = tt.stack(beta_sd_intercept, beta_sd_slope)
    
    ## 'sd' Random effect
    # intercept
    gamma_sd_intercept_sd = pm.HalfNormal('gamma_sd_intercept_sd', sd=2)
    gamma_sd_intercept_raw = pm.Normal('gamma_sd_intercept_raw', mu=0, sd=1, shape=Z_intercept.shape[1])
    gamma_sd_intercept = pm.Deterministic('gamma_sd_intercept', gamma_sd_intercept_raw * gamma_sd_intercept_sd)
    
    # slope
    gamma_sd_slope_sd = pm.HalfNormal('gamma_sd_slope_sd', sd=2)
    gamma_sd_slope_raw = pm.Normal('gamma_sd_slope_raw', mu=0, sd=1, shape=Z_slope.shape[1])
    gamma_sd_slope = pm.Deterministic('gamma_sd_slope', gamma_sd_slope_raw * gamma_sd_slope_sd)
    
    sd = tt.sqrt(tt.exp(tt.dot(np.asarray(X), beta_sd))) + \
         tt.sqrt(tt.exp(tt.dot(np.asarray(Z_intercept), gamma_sd_intercept))) + \
         tt.sqrt(tt.exp(tt.dot(np.asarray(Z_slope), gamma_sd_slope)))
    
    ## Likelihood
    likelihood = pm.Normal('likelihood', mu=mu, sd=sd, observed=data['speed'].values)

# %%
model.check_test_point()
# Out:
# beta_mu_intercept                -2.53
# beta_mu_slope                    -2.53
# gamma_mu_intercept_sd_log__      -0.77
# gamma_mu_intercept_raw          -13.78
# gamma_mu_slope_sd_log__          -0.77
# gamma_mu_slope_raw              -13.78
# beta_sd_intercept                -1.61
# beta_sd_slope                    -1.61
# gamma_sd_intercept_sd_log__      -0.77
# gamma_sd_intercept_raw          -13.78
# gamma_sd_slope_sd_log__          -0.77
# gamma_sd_slope_raw              -13.78
# likelihood                    -1625.51
# Name: Log-probability of test_point, dtype: float64

# %%
pm.model_to_graphviz(model)

# %% [markdown]
# ### Sample from the model

# %%
with model:
    trace = pm.sample(draws=SAMPLES+BURNIN, tune=TUNE, chains=4, cores=4, random_seed=SEED, nuts_kwargs={'target_accept':0.99})

# discard burnin samples
trace = trace[BURNIN:]
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [gamma_sd_slope_raw, gamma_sd_slope_sd, gamma_sd_intercept_raw, gamma_sd_intercept_sd, beta_sd_slope, beta_sd_intercept, gamma_mu_slope_raw, gamma_mu_slope_sd, gamma_mu_intercept_raw, gamma_mu_intercept_sd, beta_mu_slope, beta_mu_intercept]
# Sampling 4 chains: 100%|██████████████████████████████████████| 12000/12000 [1:10:41<00:00,  1.42draws/s]
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %% [markdown]
# ### Diagnose the sampling

# %%
pm.traceplot(trace);

# %% [markdown]
# ### Summarize the posterior density

# %%
pm.summary(trace).round(2)
# Out:
#                               mean    sd  mc_error  hpd_2.5  hpd_97.5  \
# beta_mu_intercept           100.05  0.20      0.01    99.68    100.46
# beta_mu_slope                 0.02  0.27      0.01    -0.54      0.50
# gamma_mu_intercept_raw__0     0.56  0.54      0.01    -0.55      1.57
# gamma_mu_intercept_raw__1    -1.47  0.58      0.02    -2.62     -0.37
# gamma_mu_intercept_raw__2    -1.28  0.62      0.02    -2.65     -0.18
# gamma_mu_intercept_raw__3     1.18  0.60      0.02     0.06      2.45
# gamma_mu_intercept_raw__4    -0.35  0.63      0.02    -1.59      0.86
# gamma_mu_intercept_raw__5     0.87  0.55      0.02    -0.23      1.95
# gamma_mu_intercept_raw__6     1.15  0.59      0.02     0.09      2.36
# gamma_mu_intercept_raw__7    -0.42  0.59      0.02    -1.51      0.76
# gamma_mu_intercept_raw__8     0.24  0.56      0.02    -0.83      1.41
# gamma_mu_intercept_raw__9     0.02  0.55      0.02    -1.13      1.06
# gamma_mu_intercept_raw__10    0.57  0.53      0.02    -0.44      1.64
# gamma_mu_intercept_raw__11   -0.51  0.64      0.02    -1.78      0.78
# gamma_mu_intercept_raw__12    0.31  0.55      0.02    -0.77      1.41
# gamma_mu_intercept_raw__13   -0.49  0.56      0.02    -1.58      0.63
# gamma_mu_intercept_raw__14   -0.18  0.59      0.01    -1.44      0.92
# gamma_mu_slope_raw__0        -0.70  0.44      0.02    -1.52      0.18
# gamma_mu_slope_raw__1         0.87  0.48      0.02    -0.12      1.76
# gamma_mu_slope_raw__2         0.56  0.57      0.02    -0.59      1.68
# gamma_mu_slope_raw__3        -0.24  0.49      0.02    -1.26      0.65
# gamma_mu_slope_raw__4        -1.66  0.57      0.02    -2.73     -0.55
# gamma_mu_slope_raw__5         0.01  0.44      0.02    -0.83      0.87
# gamma_mu_slope_raw__6        -1.26  0.50      0.02    -2.30     -0.36
# gamma_mu_slope_raw__7         0.73  0.48      0.02    -0.18      1.69
# gamma_mu_slope_raw__8         0.04  0.46      0.02    -0.89      0.94
# gamma_mu_slope_raw__9        -0.22  0.44      0.02    -1.12      0.57
# gamma_mu_slope_raw__10       -0.60  0.43      0.02    -1.47      0.19
# gamma_mu_slope_raw__11        1.33  0.55      0.02     0.27      2.41
# gamma_mu_slope_raw__12       -0.48  0.44      0.02    -1.30      0.41
# ...                            ...   ...       ...      ...       ...
# gamma_sd_intercept__1        -4.02  1.61      0.07    -7.20     -2.22
# gamma_sd_intercept__2        -4.49  2.86      0.07   -10.50     -0.08
# gamma_sd_intercept__3        -1.42  0.95      0.06    -2.70     -0.32
# gamma_sd_intercept__4        -1.06  0.68      0.02    -2.29     -0.02
# gamma_sd_intercept__5        -5.62  2.93      0.09   -11.09     -1.15
# gamma_sd_intercept__6        -3.74  2.31      0.09    -8.64     -1.30
# gamma_sd_intercept__7        -3.21  2.49      0.09    -8.38     -0.44
# gamma_sd_intercept__8        -4.85  2.94      0.09   -10.71     -0.44
# gamma_sd_intercept__9        -5.92  2.90      0.11   -11.51     -1.73
# gamma_sd_intercept__10      -12.30  2.18      0.04   -16.61     -9.00
# gamma_sd_intercept__11       -0.66  0.72      0.02    -2.14      0.47
# gamma_sd_intercept__12       -5.27  2.80      0.06   -10.81     -1.46
# gamma_sd_intercept__13       -5.23  3.02      0.12   -11.00     -0.14
# gamma_sd_intercept__14       -1.32  1.40      0.07    -3.56      0.22
# gamma_sd_slope_sd             4.93  0.98      0.03     3.07      6.72
# gamma_sd_slope__0            -6.72  2.70      0.09   -11.98     -2.66
# gamma_sd_slope__1            -6.61  2.68      0.08   -11.58     -2.71
# gamma_sd_slope__2             0.86  0.52      0.02    -0.14      1.75
# gamma_sd_slope__3            -6.04  2.90      0.08   -11.62     -1.27
# gamma_sd_slope__4            -5.46  2.99      0.08   -11.72     -0.99
# gamma_sd_slope__5            -2.29  1.75      0.10    -5.60     -0.52
# gamma_sd_slope__6            -4.80  2.75      0.08   -10.71     -1.41
# gamma_sd_slope__7            -3.21  2.69      0.09    -8.66     -0.27
# gamma_sd_slope__8            -0.98  0.99      0.04    -2.98      0.35
# gamma_sd_slope__9            -3.10  2.08      0.14    -7.16     -1.15
# gamma_sd_slope__10          -12.44  2.19      0.04   -16.75     -8.80
# gamma_sd_slope__11           -4.30  3.05      0.08   -10.47      0.01
# gamma_sd_slope__12           -3.11  1.87      0.06    -7.34     -1.13
# gamma_sd_slope__13           -0.60  1.15      0.09    -2.59      0.86
# gamma_sd_slope__14           -3.71  2.77      0.09    -9.32     -0.01
#
#                               n_eff  Rhat
# beta_mu_intercept            659.33  1.00
# beta_mu_slope                354.36  1.00
# gamma_mu_intercept_raw__0   1321.87  1.00
# gamma_mu_intercept_raw__1   1089.65  1.00
# gamma_mu_intercept_raw__2   1501.08  1.00
# gamma_mu_intercept_raw__3   1333.01  1.00
# gamma_mu_intercept_raw__4   1474.22  1.00
# gamma_mu_intercept_raw__5   1130.01  1.00
# gamma_mu_intercept_raw__6   1360.88  1.00
# gamma_mu_intercept_raw__7   1265.99  1.00
# gamma_mu_intercept_raw__8   1171.94  1.00
# gamma_mu_intercept_raw__9    972.81  1.00
# gamma_mu_intercept_raw__10   925.15  1.00
# gamma_mu_intercept_raw__11  1604.91  1.00
# gamma_mu_intercept_raw__12  1146.54  1.00
# gamma_mu_intercept_raw__13  1341.39  1.00
# gamma_mu_intercept_raw__14  1401.21  1.00
# gamma_mu_slope_raw__0        610.15  1.00
# gamma_mu_slope_raw__1        606.26  1.00
# gamma_mu_slope_raw__2       1369.45  1.00
# gamma_mu_slope_raw__3        816.12  1.01
# gamma_mu_slope_raw__4        754.37  1.00
# gamma_mu_slope_raw__5        592.98  1.00
# gamma_mu_slope_raw__6        854.55  1.00
# gamma_mu_slope_raw__7        934.97  1.01
# gamma_mu_slope_raw__8        632.94  1.00
# gamma_mu_slope_raw__9        569.74  1.00
# gamma_mu_slope_raw__10       582.05  1.00
# gamma_mu_slope_raw__11      1109.90  1.00
# gamma_mu_slope_raw__12       735.12  1.00
# ...                             ...   ...
# gamma_sd_intercept__1        538.59  1.00
# gamma_sd_intercept__2       1343.14  1.00
# gamma_sd_intercept__3        136.10  1.01
# gamma_sd_intercept__4        604.94  1.00
# gamma_sd_intercept__5        895.36  1.00
# gamma_sd_intercept__6        663.98  1.00
# gamma_sd_intercept__7        719.39  1.00
# gamma_sd_intercept__8       1036.86  1.00
# gamma_sd_intercept__9        610.38  1.00
# gamma_sd_intercept__10      2633.82  1.00
# gamma_sd_intercept__11       955.70  1.00
# gamma_sd_intercept__12      1383.07  1.00
# gamma_sd_intercept__13       413.88  1.01
# gamma_sd_intercept__14       207.03  1.01
# gamma_sd_slope_sd            867.88  1.00
# gamma_sd_slope__0            767.13  1.00
# gamma_sd_slope__1           1266.46  1.00
# gamma_sd_slope__2           1035.36  1.00
# gamma_sd_slope__3            954.06  1.00
# gamma_sd_slope__4           1292.01  1.00
# gamma_sd_slope__5            218.98  1.02
# gamma_sd_slope__6            973.88  1.00
# gamma_sd_slope__7            923.33  1.00
# gamma_sd_slope__8            557.35  1.00
# gamma_sd_slope__9             84.70  1.03
# gamma_sd_slope__10          2783.78  1.00
# gamma_sd_slope__11          1101.64  1.00
# gamma_sd_slope__12           804.32  1.00
# gamma_sd_slope__13            57.61  1.03
# gamma_sd_slope__14           905.17  1.00
#
# [128 rows x 7 columns]

# %% [markdown]
# ### Posterior predictive check

# %% [markdown]
# ## Statistical inference
